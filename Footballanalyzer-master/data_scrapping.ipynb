# %%
import pandas as pd

# %%
df_2025_2026 = pd.read_html('https://fbref.com/en/comps/11/Serie-A-Stats#all_results2025-2026111', 
                            attrs ={'id': 'results2025-2026111_overall'})[0]

df_2024_2025 = pd.read_html('https://fbref.com/en/comps/11/2024-2025/2024-2025-Serie-A-Stats', 
                            attrs ={'id': 'results2024-2025111_overall'})[0]

df_2023_2024 = pd.read_html('https://fbref.com/en/comps/11/2023-2024/2023-2024-Serie-A-Stats', 
                            attrs ={'id': 'results2023-2024111_overall'})[0]

df_2022_2023 = pd.read_html('https://fbref.com/en/comps/11/2022-2023/2022-2023-Serie-A-Stats', 
                            attrs ={'id': 'results2022-2023111_overall'})[0]

df_2021_2022 = pd.read_html('https://fbref.com/en/comps/11/2021-2022/2021-2022-Serie-A-Stats', 
                            attrs ={'id': 'results2021-2022111_overall'})[0]

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
df_2025_2026.head()
# Out:
#    Rk    Squad  MP  W  D  L  GF  GA  GD  Pts  Pts/MP    xG  xGA  xGD  xGD/90  \
# 0   1    Milan   7  5  1  1  11   4   7   16    2.29  10.5  5.7  4.8    0.68
# 1   2    Inter   7  5  0  2  18   8  10   15    2.14  13.1  5.7  7.4    1.06
# 2   3   Napoli   7  5  0  2  12   7   5   15    2.14  12.4  8.2  4.2    0.59
# 3   4     Roma   7  5  0  2   7   3   4   15    2.14   8.2  5.8  2.5    0.35
# 4   5  Bologna   7  4  1  2  11   5   6   13    1.86   9.4  5.9  3.5    0.49
#
#       Last 5  Attendance                         Top Team Scorer  \
# 0  W W W D W       72458                   Christian Pulisic - 4
# 1  L W W W W       70683  Marcus Thuram, Lautaro Martínez... - 3
# 2  W W L W L       50270                     Kevin De Bruyne - 3
# 3  L W W W L       63625                        Matìas Soulé - 3
# 4  L W D W W       28106                   Riccardo Orsolini - 5
#
#          Goalkeeper  Notes
# 0      Mike Maignan    NaN
# 1       Yann Sommer    NaN
# ...

# %%
dfs = [df_2025_2026, df_2024_2025, df_2023_2024, df_2022_2023, df_2021_2022]

for df in dfs:
    df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

forventet_columns = [
    "Rk", "Squad", "MP", "W", "D", "L",
    "GF", "GA", "GD", "Pts", "Pts/MP",
    "xG", "xGA", "xGD", "xGD/90",
    "Last_5", "Attendance", "Top_Scorer", "Goalkeeper", "Notes"
]

aar =list(range(2020, 2025))
for df, aar in zip(dfs, aar):
    df["sesonger"] = aar

full_data = pd.concat(dfs, ignore_index=True)

# %%
print(full_data.shape)
full_data.head()
# Out:
# (100, 21)
#    rk    squad  mp  w  d  l  gf  ga  gd  pts  pts/mp    xg  xga  xgd  xgd/90  \
# 0   1    Milan   7  5  1  1  11   4   7   16    2.29  10.5  5.7  4.8    0.68
# 1   2    Inter   7  5  0  2  18   8  10   15    2.14  13.1  5.7  7.4    1.06
# 2   3   Napoli   7  5  0  2  12   7   5   15    2.14  12.4  8.2  4.2    0.59
# 3   4     Roma   7  5  0  2   7   3   4   15    2.14   8.2  5.8  2.5    0.35
# 4   5  Bologna   7  4  1  2  11   5   6   13    1.86   9.4  5.9  3.5    0.49
#
#       last_5  attendance                         top_team_scorer  \
# 0  W W W D W       72458                   Christian Pulisic - 4
# 1  L W W W W       70683  Marcus Thuram, Lautaro Martínez... - 3
# 2  W W L W L       50270                     Kevin De Bruyne - 3
# 3  L W W W L       63625                        Matìas Soulé - 3
# 4  L W D W W       28106                   Riccardo Orsolini - 5
#
#          goalkeeper notes  sesonger
# 0      Mike Maignan   NaN      2020
# ...

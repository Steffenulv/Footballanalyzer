# %%
import pandas as pd

# %%
df_2025_2026 = pd.read_html('https://fbref.com/en/comps/11/Serie-A-Stats#all_results2025-2026111', 
                            attrs ={'id': 'results2025-2026111_overall'})[0]

# %%
df_2025_2026
# Out:
#     Rk          Squad  MP  W  D  L  GF  GA  GD  Pts  Pts/MP    xG   xGA  xGD  \
# 0    1          Milan   7  5  1  1  11   4   7   16    2.29  10.5   5.7  4.8
# 1    2          Inter   7  5  0  2  18   8  10   15    2.14  13.1   5.7  7.4
# 2    3         Napoli   7  5  0  2  12   7   5   15    2.14  12.4   8.2  4.2
# 3    4           Roma   7  5  0  2   7   3   4   15    2.14   8.2   5.8  2.5
# 4    5        Bologna   7  4  1  2  11   5   6   13    1.86   9.4   5.9  3.5
# 5    6           Como   7  3  3  1   9   5   4   12    1.71   9.1   6.7  2.4
# 6    7       Juventus   7  3  3  1   9   7   2   12    1.71   7.9   7.5  0.4
# 7    8       Atalanta   7  2  5  0  11   5   6   11    1.57  10.6   6.1  4.5
# 8    9       Sassuolo   7  3  1  3   8   8   0   10    1.43   7.1   9.5 -2.3
# 9   10      Cremonese   7  2  4  1   8   9  -1   10    1.43   5.4  11.0 -5.6
# 10  11        Udinese   7  2  3  2   7  10  -3    9    1.29   8.0   7.5  0.5
# ...
